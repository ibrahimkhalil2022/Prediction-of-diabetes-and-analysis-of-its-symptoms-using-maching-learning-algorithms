# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re

from sklearn.svm import SVC

from pandas import DataFrame

# %%
# Read data in the excel file
df = pd.read_csv('dataset.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
# Get min, max and average of the age
print('Min age: ', min(df['Age']))
print('Max age: ', max(df['Age']))
print('Average age: ', df['Age'].mean())
# Out:
# Min age:  21
# Max age:  81
# Average age:  33.240885416666664

# %%
df = df.drop(df.index[df['Age'] < 60])
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 30             5      109             75             26        0  36.0
# 93             4      134             72              0        0  23.8
# 115            4      146             92              0        0  31.2
# 123            5      132             80              0        0  26.8
# 129            0      105             84              0        0  27.9
# 148            5      147             78              0        0  33.7
# 186            8      181             68             36      495  30.1
# 212            7      179             95             31        0  34.2
# 221            2      158             90              0        0  31.6
# 223            7      142             60             33      190  28.8
# 263            3      142             80             15        0  32.4
# 294            0      161             50              0        0  21.9
# 361            5      158             70              0        0  29.8
# 362            5      103            108             37        0  39.2
# 363            4      146             78              0        0  38.5
# 453            2      119              0              0        0  19.6
# 456            1      135             54              0        0  26.7
# 459            9      134             74             33       60  25.9
# 479            4      132             86             31        0  28.0
# 489            8      194             80              0        0  26.1
# 495            6      166             74              0        0  26.6
# 509            8      120             78              0        0  25.0
# 519            6      129             90              7      326  19.6
# 537            0       57             60              0        0  21.7
# 552            6      114             88              0        0  27.8
# 579            2      197             70             99        0  34.7
# 582           12      121             78             17        0  26.5
# 666            4      145             82             18        0  32.5
# 674            8       91             82              0        0  35.6
# 684            5      136             82              0        0   0.0
# 759            6      190             92              0        0  35.5
# 763           10      101             76             48      180  32.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 30                      0.546   60        0
# 93                      0.277   60        1
# 115                     0.539   61        1
# 123                     0.186   69        0
# 129                     0.741   62        1
# 148                     0.218   65        0
# 186                     0.615   60        1
# 212                     0.164   60        0
# 221                     0.805   66        1
# 223                     0.687   61        0
# 263                     0.200   63        0
# 294                     0.254   65        0
# 361                     0.207   63        0
# 362                     0.305   65        0
# 363                     0.520   67        1
# 453                     0.832   72        0
# 456                     0.687   62        0
# 459                     0.460   81        0
# 479                     0.419   63        0
# 489                     0.551   67        0
# 495                     0.304   66        0
# 509                     0.409   64        0
# 519                     0.582   60        0
# 537                     0.735   67        0
# 552                     0.247   66        0
# 579                     0.575   62        1
# 582                     0.259   62        0
# 666                     0.235   70        1
# 674                     0.587   68        0
# 684                     0.640   69        0
# 759                     0.278   66        1
# 763                     0.171   63        0

# %%
df.to_csv(r'g3.csv')

# %%
# Read data in the excel file
data = pd.read_csv('g3.csv')
data
# Out:
#     Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0           30            5      109             75             26        0
# 1           93            4      134             72              0        0
# 2          115            4      146             92              0        0
# 3          123            5      132             80              0        0
# 4          129            0      105             84              0        0
# 5          148            5      147             78              0        0
# 6          186            8      181             68             36      495
# 7          212            7      179             95             31        0
# 8          221            2      158             90              0        0
# 9          223            7      142             60             33      190
# 10         263            3      142             80             15        0
# 11         294            0      161             50              0        0
# 12         361            5      158             70              0        0
# 13         362            5      103            108             37        0
# 14         363            4      146             78              0        0
# 15         453            2      119              0              0        0
# 16         456            1      135             54              0        0
# 17         459            9      134             74             33       60
# 18         479            4      132             86             31        0
# 19         489            8      194             80              0        0
# 20         495            6      166             74              0        0
# 21         509            8      120             78              0        0
# 22         519            6      129             90              7      326
# 23         537            0       57             60              0        0
# 24         552            6      114             88              0        0
# 25         579            2      197             70             99        0
# 26         582           12      121             78             17        0
# 27         666            4      145             82             18        0
# 28         674            8       91             82              0        0
# 29         684            5      136             82              0        0
# 30         759            6      190             92              0        0
# 31         763           10      101             76             48      180
#
#      BMI  DiabetesPedigreeFunction  Age  Outcome
# 0   36.0                     0.546   60        0
# 1   23.8                     0.277   60        1
# 2   31.2                     0.539   61        1
# 3   26.8                     0.186   69        0
# 4   27.9                     0.741   62        1
# 5   33.7                     0.218   65        0
# 6   30.1                     0.615   60        1
# 7   34.2                     0.164   60        0
# 8   31.6                     0.805   66        1
# 9   28.8                     0.687   61        0
# 10  32.4                     0.200   63        0
# 11  21.9                     0.254   65        0
# 12  29.8                     0.207   63        0
# 13  39.2                     0.305   65        0
# 14  38.5                     0.520   67        1
# 15  19.6                     0.832   72        0
# 16  26.7                     0.687   62        0
# 17  25.9                     0.460   81        0
# 18  28.0                     0.419   63        0
# 19  26.1                     0.551   67        0
# 20  26.6                     0.304   66        0
# 21  25.0                     0.409   64        0
# 22  19.6                     0.582   60        0
# 23  21.7                     0.735   67        0
# 24  27.8                     0.247   66        0
# 25  34.7                     0.575   62        1
# 26  26.5                     0.259   62        0
# 27  32.5                     0.235   70        1
# 28  35.6                     0.587   68        0
# 29   0.0                     0.640   69        0
# 30  35.5                     0.278   66        1
# 31  32.9                     0.171   63        0

# %%
#print('Max Glucose: ', max(data['Glucose']))

# %%
#data_g1 = data.loc[data['Glucose'] == 197]
#data_g1

# %%
data['Glucose'].plot(kind = 'hist', title = 'Glucose', figsize = (8, 6),bins=20, rwidth=0.9, color='#607c8e')

#plt.ylim([0, 30])
plt.title('Age Group 3 "Glucose Level"')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(axis='y')


plt.show()

# %%
data['BloodPressure'].plot(kind = 'hist', title = 'BloodPressure', figsize = (8, 6),bins=20, rwidth=0.9, color='#607c8e')

#plt.ylim([0, 30])
plt.title('Age Group 2 "BloodPressure Level"')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(axis='y')


plt.show()

# %%
data['SkinThickness'].plot(kind = 'hist', title = 'SkinThickness', figsize = (8, 6),bins=20, rwidth=0.9, color='#607c8e')

#plt.ylim([0, 30])
plt.title('Age Group 2 "SkinThickness Level"')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(axis='y')


plt.show()

# %%
data['Insulin'].plot(kind = 'hist', title = 'Insulin', figsize = (8, 6),bins=20, rwidth=0.9, color='#607c8e')

#plt.ylim([0, 30])
plt.title('Age Group 2 "Insulin Level"')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(axis='y')


plt.show()

# %%
data['BMI'].plot(kind = 'hist', title = 'BMI', figsize = (8, 6),bins=20, rwidth=0.9, color='#607c8e')

#plt.ylim([0, 30])
plt.title('Age Group 1 "BMI Level"')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(axis='y')


plt.show()

# %%
data['DiabetesPedigreeFunction'].plot(kind = 'hist', title = 'DiabetesPedigreeFunction', figsize = (8, 6),bins=20, rwidth=0.9, color='#607c8e')

#plt.ylim([0, 30])
plt.title('Age Group 2 "DiabetesPedigreeFunction Level"')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(axis='y')


plt.show()
